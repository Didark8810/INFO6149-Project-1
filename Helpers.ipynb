# %%
try:
    import secml
except ImportError:
    # %pip install git+https://github.com/pralab/secml

try:
    import foolbox
except:
    # %pip install foolbox

try:
    import robustbench
except ImportError:
    # %pip install git+https://github.com/RobustBench/robustbench.git

# %%
from secml.adv.attacks.evasion import CFoolboxPGDLinf

# %%
print("\n".join(dir(secml.adv.attacks.evasion)))
# Out:
# CAttackEvasion
# CAttackEvasionFoolbox
# CAttackEvasionPGD
# CAttackEvasionPGDExp
# CAttackEvasionPGDLS
# CFoolboxBasicIterative
# CFoolboxBasicIterativeL1
# CFoolboxBasicIterativeL2
# CFoolboxBasicIterativeLinf
# CFoolboxDeepfool
# CFoolboxDeepfoolL2
# CFoolboxDeepfoolLinf
# CFoolboxEAD
# CFoolboxFGM
# CFoolboxFGML1
# CFoolboxFGML2
# CFoolboxFGMLinf
# CFoolboxL2CarliniWagner
# CFoolboxL2DDN
# CFoolboxPGD
# CFoolboxPGDL1
# CFoolboxPGDL2
# CFoolboxPGDLinf
# SecmlLayer
# __builtins__
# __cached__
# __doc__
# __file__
# __loader__
# __name__
# __package__
# __path__
# __spec__
# c_attack_evasion
# c_attack_evasion_pgd
# c_attack_evasion_pgd_exp
# c_attack_evasion_pgd_ls
# foolbox
# torch

# %%
help(secml.adv.attacks.evasion.CFoolboxPGDLinf.run)
# Out:
# Help on function run in module secml.adv.attacks.evasion.c_attack_evasion:
#
# run(self, x, y, ds_init=None)
#     Runs evasion on a dataset.
#
#     Parameters
#     ----------
#     x : CArray
#         Data points.
#     y : CArray
#         True labels.
#     ds_init : CDataset
#         Dataset for warm starts.
#
#     Returns
#     -------
#     y_pred : CArray
#         Predicted labels for all ds samples by target classifier.
#     scores : CArray
#         Scores for all ds samples by target classifier.
#     adv_ds : CDataset
#         Dataset of manipulated samples.
#     f_obj : float
#         Mean value of the objective function computed on each data point.

# %%
help(secml.adv.attacks.evasion.CFoolboxDeepfoolLinf.run)
# Out:
# Help on function run in module secml.adv.attacks.evasion.c_attack_evasion:
#
# run(self, x, y, ds_init=None)
#     Runs evasion on a dataset.
#
#     Parameters
#     ----------
#     x : CArray
#         Data points.
#     y : CArray
#         True labels.
#     ds_init : CDataset
#         Dataset for warm starts.
#
#     Returns
#     -------
#     y_pred : CArray
#         Predicted labels for all ds samples by target classifier.
#     scores : CArray
#         Scores for all ds samples by target classifier.
#     adv_ds : CDataset
#         Dataset of manipulated samples.
#     f_obj : float
#         Mean value of the objective function computed on each data point.

# %%
help(secml.data.loader)
# Out:
# Help on package secml.data.loader in secml.data:
#
# NAME
#     secml.data.loader
#
# PACKAGE CONTENTS
#     c_dataloader
#     c_dataloader_cifar
#     c_dataloader_icubworld
#     c_dataloader_imgclients
#     c_dataloader_imgfolders
#     c_dataloader_lfw
#     c_dataloader_mnist
#     c_dataloader_pytorch
#     c_dataloader_sklearn
#     c_dataloader_svmlight
#     loader_utils
#
# FILE
#     /opt/anaconda3/envs/p3.9/lib/python3.9/site-packages/secml/data/loader/__init__.py

# %%
help(secml.adv.attacks.evasion)
# Out:
# Help on package secml.adv.attacks.evasion in secml.adv.attacks:
#
# NAME
#     secml.adv.attacks.evasion
#
# PACKAGE CONTENTS
#     c_attack_evasion
#     c_attack_evasion_pgd
#     c_attack_evasion_pgd_exp
#     c_attack_evasion_pgd_ls
#     cleverhans (package)
#     foolbox (package)
#
# FILE
#     /opt/anaconda3/envs/p3.9/lib/python3.9/site-packages/secml/adv/attacks/evasion/__init__.py

# %%
help(CFoolboxL2CarliniWagner)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 help(CFoolboxL2CarliniWagner)
#
# NameError: name 'CFoolboxL2CarliniWagner' is not defined

# %%
help(secml.adv.attacks.evasion.CFoolboxDeepfoolLinf)
# Out:
# Help on class CFoolboxDeepfoolLinf in module secml.adv.attacks.evasion.foolbox.fb_attacks.fb_deepfool_attack:
#
# class CFoolboxDeepfoolLinf(CFoolboxDeepfool)
#  |  CFoolboxDeepfoolLinf(classifier, y_target=None, lb=0.0, ub=1.0, epsilons=0.2, steps=50, candidates=10, overshoot=0.02, loss='logits')
#  |
#  |  Method resolution order:
#  |      CFoolboxDeepfoolLinf
#  |      CFoolboxDeepfool
#  |      secml.adv.attacks.evasion.foolbox.losses.deepfool_loss.DeepfoolLoss
#  |      secml.adv.attacks.evasion.foolbox.c_attack_evasion_foolbox.CAttackEvasionFoolbox
#  |      secml.adv.attacks.evasion.c_attack_evasion.CAttackEvasion
#  |      secml.adv.attacks.c_attack.CAttack
#  |      secml.core.c_creator.CCreator
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, classifier, y_target=None, lb=0.0, ub=1.0, epsilons=0.2, steps=50, candidates=10, overshoot=0.02, loss='logits')
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
# ...

# %%
help(secml.adv.attacks.evasion.CFoolboxPGDLinf)
# Out:
# Help on class CFoolboxPGDLinf in module secml.adv.attacks.evasion.foolbox.fb_attacks.fb_pgd_attack:
#
# class CFoolboxPGDLinf(CFoolboxPGD)
#  |  CFoolboxPGDLinf(classifier, y_target=None, lb=0.0, ub=1.0, epsilons=0.2, rel_stepsize=0.025, abs_stepsize=None, steps=50, random_start=True)
#  |
#  |  Method resolution order:
#  |      CFoolboxPGDLinf
#  |      CFoolboxPGD
#  |      secml.adv.attacks.evasion.foolbox.losses.ce_loss.CELoss
#  |      secml.adv.attacks.evasion.foolbox.c_attack_evasion_foolbox.CAttackEvasionFoolbox
#  |      secml.adv.attacks.evasion.c_attack_evasion.CAttackEvasion
#  |      secml.adv.attacks.c_attack.CAttack
#  |      secml.core.c_creator.CCreator
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, classifier, y_target=None, lb=0.0, ub=1.0, epsilons=0.2, rel_stepsize=0.025, abs_stepsize=None, steps=50, random_start=True)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
# ...
